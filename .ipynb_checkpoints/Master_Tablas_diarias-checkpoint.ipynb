# %%
import pandas as pd
import requests
from urllib.request import urlopen
import json

# %%
url=urlopen('https://sedeaplicaciones.minetur.gob.es/ServiciosRESTCarburantes/PreciosCarburantes/EstacionesTerrestres/')
df=url.read().decode('utf-8', 'replace')


#response = urlopen("https://bittrex.com/api/v1.1/public/getmarkethistory?market=BTC-ETC")
#json_data = response.read().decode('utf-8', 'replace')

# %%
d = json.loads(df)
df_1 = pd.json_normalize(d['ListaEESSPrecio'])

# %%
df_1
# Out:
#         C.P.                                          Dirección  \
# 0      02250                     AVENIDA CASTILLA LA MANCHA, 26
# 1      02152                                    CR CM-332, 46,4
# 2      02001  CALLE PRINCIPE DE ASTURIAS (POLÍGONO DE ROMICA...
# 3      02001                            AVENIDA 1º DE MAYO, S/N
# 4      02001                     CALLE FEDERICO GARCIA LORCA, 5
# ...      ...                                                ...
# 11811  50197                 RONDA FERIA DE MUESTRAS, DE LA, 20
# 11812  50197                         AVENIDA DIAGONAL PLAZA, 22
# 11813  50800                        CARRETERA N-330A KM. 24,000
# 11814  50800                               CALLE AUSTRIA, 11,17
# 11815  50810                               CALLE COOPERATIVA, 2
#
#                                 Horario    Latitud        Localidad  \
# 0                      L-D: 07:00-22:00  39,211417        ABENGIBRE
# 1                       L-D: 7:00-23:00  39,100389           ALATOZ
# 2                      L-D: 06:00-21:30  39,054694         ALBACETE
# 3      L-S: 08:00-22:00; D: 09:00-21:00  38,985667         ALBACETE
# 4                      L-S: 05:00-23:00  38,997722         ALBACETE
# ...                                 ...        ...              ...
# 11811                          L-D: 24H  41,637944         ZARAGOZA
# 11812  L-V: 06:00-22:00; S: 08:00-15:00  41,636528         ZARAGOZA
# 11813                  L-D: 06:00-22:00  41,857000            ZUERA
# 11814                          L-D: 24H  41,883583            ZUERA
# 11815                          L-D: 24H  41,938750  ONTINAR DE SALZ
#
#       Longitud (WGS84) Margen  Municipio Precio Biodiesel Precio Bioetanol  \
# 0            -1,539167      D  Abengibre
# 1            -1,346083      I     Alatoz
# 2            -1,832000      I   Albacete
# 3            -1,868500      N   Albacete
# 4            -1,846361      I   Albacete
# ...                ...    ...        ...              ...              ...
# 11811        -0,986389      D   Zaragoza
# 11812        -0,990111      D   Zaragoza
# 11813        -0,794000      D      Zuera
# 11814        -0,782833      D      Zuera
# 11815        -0,757611      D      Zuera
#
#        ... Provincia Remisión                  Rótulo Tipo Venta % BioEtanol  \
# 0      ...  ALBACETE       dm               Nº 10.935          P         0,0
# 1      ...  ALBACETE       dm                  REPSOL          P         0,0
# 2      ...  ALBACETE       OM               BP ROMICA          P         0,0
# 3      ...  ALBACETE       dm               CARREFOUR          P         0,0
# 4      ...  ALBACETE       dm                   CEPSA          R         0,0
# ...    ...       ...      ...                     ...        ...         ...
# 11811  ...  ZARAGOZA       OM                     IDS          P         0,0
# 11812  ...  ZARAGOZA       dm                  REPSOL          P         0,0
# 11813  ...  ZARAGOZA       OM                  REPSOL          P         0,0
# 11814  ...  ZARAGOZA       dm    AN ENERGETICOS ZUERA          P         0,0
# 11815  ...  ZARAGOZA       dm  COOPERATIVA SAN ISIDRO          P         0,0
#
#       % Éster metílico IDEESS IDMunicipio IDProvincia IDCCAA
# 0                  0,0   4375          52          02     07
# 1                  0,0   5122          53          02     07
# 2                  0,0  12054          54          02     07
# 3                  0,0  10765          54          02     07
# 4                  0,0   4438          54          02     07
# ...                ...    ...         ...         ...    ...
# 11811              0,0  12472        8108          50     02
# 11812              0,0  12289        8108          50     02
# 11813              0,0   1452        8109          50     02
# 11814              0,0   9085        8109          50     02
# 11815              0,0   9068        8109          50     02
#
# [11816 rows x 32 columns]

# %%
df_1.to_csv('2022-10-24.csv', index=False)
